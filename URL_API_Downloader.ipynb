# %% [markdown]
# # 기상청 OPEN URL API 서비스

# %%
import requests  # to make GET request
import re
import calendar
import time


satgk2aobs = 'http://203.247.66.126:8090/url/sat_gk2a_obs_file.php?'
satgk2aana = "http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?"
ir096 = "&ch=ir096&map=ko&authKey="
vi004 = "&ch=vi004&map=ko&authKey="
cla = "&ch=cla&map=ko&authKey="
authKey = ["junhuk1113@naver.com","dotoro.kim@gmail.com","dspkhan@hanmail.net","redcar1024@gmail.com","ohsun8436@nate.com","junhuk1113@gmail.com","junhuk1113@daum.net"]
      
def download(url,authkeycode):
    while True:
        
        try:
            print("Requesting url data")
            counter(authkeycode)
            r = requests.get(url,timeout=2)
            if(r.text[0]=='#'):
                return "file not exist"
            elif(r.text[0]=='<'):
                return "The number of requests has reached the limit"
            d = r.headers['content-disposition']
        except :
            print("time out, 1sec delaying..")
            time.sleep(1)
        else: 
            break
    file_name = re.findall("filename=\"(.+)\"", d)[0]

    with open("D:/VSCODE/weather_resource/download/"+file_name, "wb") as file:   # open in binary mode
                    # get request
        file.write(r.content)      # write to file
    return file_name + " saved successfully!"

def counter(authkey):
    f = open("request_Count.txt","r")
    data=f.readline()
    f.close()
    data=data.split()
    data[authkey]=str(int(data[authkey]) + 1)
    f = open("request_Count.txt","w")
    #print(data)
    f.write(' '.join(data))
    f.close()
    return data
def geturl(sat, ch, month,day,hour,authkeycode):
    if month < 10:
        month = "0" +str(month)
    else: month = str(month)
    if day < 10:
        day = "0" +str(day)
    else: day = str(day)
    if hour < 10:
        hour = "0" +str(hour)
    else: hour = str(hour)
    url = sat + "tm=2021" +month+day+hour+"00"+ch+authKey[authkeycode]
    return url

# %%
authkeycode =0

for month in range(1,2):
    monrange = calendar.monthrange(2021,month)
    for day in range(1,monrange[1]+1):
        hour = 0
        while hour<24:
            url=geturl(satgk2aana,cla,month,day,hour,authkeycode)
            print(url)
            result=download(url,authkeycode)
            print(result)
            if result=="The number of requests has reached the limit":
                authkeycode += 1
                hour -= 1
            #seldown(url)
            time.sleep(1)
            hour += 1
# Out:
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010000&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010100&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010200&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010300&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010400&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010500&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010600&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010700&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010800&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101010900&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101010900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011000&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011100&ch=cla&map=ko&authKey=junhuk1113@naver.com
# Requesting url data
# The number of requests has reached the limit
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101011900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101011900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101012000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101012000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101012100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101012100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101012200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101012200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101012300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101012300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# file not exist
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101020900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101020900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101021900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101021900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101022000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101022000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101022100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101022100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101022200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101022200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101022300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101022300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101030900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101030900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101031900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101031900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101032000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101032000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101032100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101032100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101032200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101032200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101032300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101032300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101040900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101040900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101041900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101041900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101042000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101042000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101042100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101042100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101042200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101042200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101042300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101042300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101050900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101050900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101051900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101051900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101052000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101052000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101052100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101052100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101052200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101052200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101052300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101052300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101060900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101060900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101061900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101061900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101062000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101062000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101062100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101062100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101062200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101062200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101062300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101062300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101070900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101070900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101071900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101071900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101072000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101072000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101072100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101072100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101072200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101072200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101072300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101072300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101080900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101080900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081800&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101081900&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101081900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101082000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101082000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101082100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101082100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101082200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101082200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101082300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101082300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090000&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090100&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090200&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090300&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090400&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090500&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090600&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101090600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101090700&ch=cla&map=ko&authKey=dotoro.kim@gmail.com
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# ...
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101282000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101282100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101282100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101282200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101282200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101282300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101282300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101290900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101290900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101291900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101291900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101292000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101292000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101292100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101292100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101292200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101292200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101292300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101292300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101300900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101300900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101301900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101301900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101302000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101302000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101302100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101302100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101302200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101302200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101302300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101302300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101310900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101310900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311300.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311400&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# time out, 1sec delaying..
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311400.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311500&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311500.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311600&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311600.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311700&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311700.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311800&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311800.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101311900&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101311900.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101312000&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101312000.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101312100&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101312100.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101312200&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101312200.nc saved successfully!
# http://203.247.66.126:8090/url/sat_gk2a_ana_file.php?tm=202101312300&ch=cla&map=ko&authKey=dspkhan@hanmail.net
# Requesting url data
# gk2a_ami_le2_cla_ko020lc_202101312300.nc saved successfully!

# %% [markdown]
# ---
